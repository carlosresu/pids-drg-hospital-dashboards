# %% [markdown]
# # Export Hospital Level Dashboards
#
# **Purpose:**
#
# 1. **Optionally authenticate** with `gcloud` (via user prompt).
# 2. **Query BigQuery** for facility names (`faci_name` from `drg-viz.00_datasets.hci`).
# 3. **(Optional) Save** these names to a local CSV for debugging.
# 4. **Launch Selenium** (using `a_source_chrome_webdriver.py`) to open Power BI in **headless** mode,
#    select each facility in the slicer, and **export** a PDF to `./hospital-reports`.

# %%
import os
import sys
import json

# Third-party imports
from google.cloud import bigquery
from google.api_core.exceptions import GoogleAPIError

# Local imports (the new approach)
project_root = os.path.expanduser("~/pids-drg-hospital-dashboards")
if project_root not in sys.path:
    sys.path.append(project_root)

from src.functions import *

# Define the path for saving adaptive wait times
WAIT_TIMES_JSON = os.path.join("..", "data", "cache", "final_wait_times.json")

def main():
    """
    Main function that:
      1) Loads (or initializes) the WAIT_TIMES.
      2) In debug mode, runs a calibration routine that tunes one wait time
         at a time (processing one hospital) to determine the minimal wait time needed.
      3) In non-debug mode, it uses the saved wait times and processes hospitals as usual.
      4) The final wait times are saved to WAIT_TIMES_JSON.
    """
    # Load wait times if the JSON exists; otherwise, initialize to 10 seconds for all.
    if os.path.isfile(WAIT_TIMES_JSON):
        with open(WAIT_TIMES_JSON, "r") as f:
            wait_times = json.load(f)
        print(f"Loaded WAIT_TIMES from {WAIT_TIMES_JSON}: {wait_times}")
    else:
        wait_times = {
            "iframe_wait": 5,
            "dropdown_sleep": 15,
            "search_sleep": 10,
            "visual_update_sleep": 15,
            "webdriver_wait_first_result": 15
        }
        print("No existing wait times found; initializing WAIT_TIMES to 10 for all steps.")
    
    # Update the global WAIT_TIMES in functions.py
    from src.functions import WAIT_TIMES
    WAIT_TIMES.clear()
    WAIT_TIMES.update(wait_times)
    
    # If in debug mode, calibrate each wait time one by one.
    # The calibration process runs test runs on a single hospital.
    if TO_DEBUG:
        print("\nStarting calibration of wait times...")
        calibrate_wait_times()
    else:
        # In non-debug mode, run a full attempt.
        attempt_run()

    # Save the final wait times to JSON
    os.makedirs(os.path.dirname(WAIT_TIMES_JSON), exist_ok=True)
    with open(WAIT_TIMES_JSON, "w") as f:
        json.dump(WAIT_TIMES, f)
    print(f"\nSaved final WAIT_TIMES to {WAIT_TIMES_JSON}.")

if __name__ == "__main__":
    main()
# Out:
# Requirement already satisfied: selenium>=4.8.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from -r ../requirements.txt (line 1)) (4.34.0)
# Requirement already satisfied: requests>=2.25.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from -r ../requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: urllib3~=2.4.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from urllib3[socks]~=2.4.0->selenium>=4.8.0->-r ../requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: trio~=0.30.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from selenium>=4.8.0->-r ../requirements.txt (line 1)) (0.30.0)
# Requirement already satisfied: trio-websocket~=0.12.2 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from selenium>=4.8.0->-r ../requirements.txt (line 1)) (0.12.2)
# Requirement already satisfied: certifi>=2025.4.26 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from selenium>=4.8.0->-r ../requirements.txt (line 1)) (2025.6.15)
# Requirement already satisfied: typing_extensions~=4.14.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from selenium>=4.8.0->-r ../requirements.txt (line 1)) (4.14.0)
# Requirement already satisfied: websocket-client~=1.8.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from selenium>=4.8.0->-r ../requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests>=2.25.0->-r ../requirements.txt (line 2)) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from requests>=2.25.0->-r ../requirements.txt (line 2)) (3.10)
# Requirement already satisfied: attrs>=23.2.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from trio~=0.30.0->selenium>=4.8.0->-r ../requirements.txt (line 1)) (25.3.0)
# Requirement already satisfied: sortedcontainers in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from trio~=0.30.0->selenium>=4.8.0->-r ../requirements.txt (line 1)) (2.4.0)
# Requirement already satisfied: outcome in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from trio~=0.30.0->selenium>=4.8.0->-r ../requirements.txt (line 1)) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from trio~=0.30.0->selenium>=4.8.0->-r ../requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from trio-websocket~=0.12.2->selenium>=4.8.0->-r ../requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from urllib3[socks]~=2.4.0->selenium>=4.8.0->-r ../requirements.txt (line 1)) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /Users/carlosresu/.pyenv/versions/3.13.2/lib/python3.13/site-packages (from wsproto>=0.14->trio-websocket~=0.12.2->selenium>=4.8.0->-r ../requirements.txt (line 1)) (0.16.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
